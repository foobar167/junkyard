# %% [markdown]
# # Contrastive Learning Exercise
#
# [5 minutes video](https://youtu.be/sftIkJ8MYL4) to get acquainted with the Contrastive Learning.
#
# [Full Guide to Contrastive Learning](https://encord.com/blog/guide-to-contrastive-learning/), 8-15 minutes reading.
#
# [The Beginner’s Guide to Contrastive Learning](https://www.v7labs.com/blog/contrastive-learning-guide), 30-60 minutes reading.
#
# **Contrastive learning** is a machine learning technique used to learn meaningful representations from data by contrasting similar and dissimilar examples. It aims to train a model to differentiate between instances, pulling representations of similar pairs closer together while pushing dissimilar pairs further apart in a feature space. This approach is particularly useful for **self-supervised learning**, where labeled data is scarce or unavailable.

# %% [markdown]
# ## Tasks
#    * Investigate training of different neural network achitectures with and without usage of Contrastive Learning. The pipleline for investigation is in the Colab [Fine tuning and Contrastive Learning](https://colab.research.google.com/drive/1yKbqVIP7JtgWPf-OiLy1qLEoNEo1wQrk).
#    * Add Dropout layer at the end of ResNet50 neural network. Have the results improved?
#    * *Optional:* Try to unfreeze ResNet50 model layer by layer after several epochs of training. Have the results improved?
